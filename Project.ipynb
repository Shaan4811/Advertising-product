# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/Users/shaan/Desktop/data analytics/Matplotlib(Visualization)/Project 1/Time-Wasters on Social Media.csv')

# %%
data
# Out:
#      UserID  Age  Gender       Location  Income   Debt  Owns Property  \
# 0         1   56    Male       Pakistan   82812   True           True
# 1         2   46  Female         Mexico   27999  False           True
# 2         3   32  Female  United States   42436  False           True
# 3         4   60    Male         Barzil   62963   True          False
# 4         5   25    Male       Pakistan   22096  False           True
# ..      ...  ...     ...            ...     ...    ...            ...
# 995     996   22    Male          India   74254   True           True
# 996     997   40  Female       Pakistan   27006  False          False
# 997     998   27    Male          India   94218   True           True
# 998     999   61    Male       Pakistan   85344   True          False
# 999    1000   19    Male          India   53840   True           True
#
#         Profession Demographics   Platform  ...  ProductivityLoss  \
# ...

# %%
pd.set_option('display.max_columns',85)

# %%
# used to see maximum columns

# %%
data
# Out:
#      UserID  Age  Gender       Location  Income   Debt  Owns Property  \
# 0         1   56    Male       Pakistan   82812   True           True
# 1         2   46  Female         Mexico   27999  False           True
# 2         3   32  Female  United States   42436  False           True
# 3         4   60    Male         Barzil   62963   True          False
# 4         5   25    Male       Pakistan   22096  False           True
# ..      ...  ...     ...            ...     ...    ...            ...
# 995     996   22    Male          India   74254   True           True
# 996     997   40  Female       Pakistan   27006  False          False
# 997     998   27    Male          India   94218   True           True
# 998     999   61    Male       Pakistan   85344   True          False
# 999    1000   19    Male          India   53840   True           True
#
#         Profession Demographics   Platform  Total Time Spent  \
# 0         Engineer        Rural  Instagram                80
# ...

# %%
data.columns
# Out:
# Index(['UserID', 'Age', 'Gender', 'Location', 'Income', 'Debt',
#        'Owns Property', 'Profession', 'Demographics', 'Platform',
#        'Total Time Spent', 'Number of Sessions', 'Video ID', 'Video Category',
#        'Video Length', 'Engagement', 'Importance Score', 'Time Spent On Video',
#        'Number of Videos Watched', 'Scroll Rate', 'Frequency',
#        'ProductivityLoss', 'Satisfaction', 'Watch Reason', 'DeviceType', 'OS',
#        'Watch Time', 'Self Control', 'Addiction Level', 'CurrentActivity',
#        'ConnectionType'],
#       dtype='object')

# %%
# ## Columns Description
# * UserID: Unique identifier assigned to each user.
# * Age: The user's age. - Gender: The user's gender (e.g., male, female, non-binary).
# * Location: Geographic location of the user.
# * Income: The user's income level.
# * Debt: Amount of debt the user has.
# * Owns Property: Indicates whether the user owns property.
# * Profession: The user's occupation or job.
# * Demographics: Statistical data about the user (e.g., age, gender, income).
# * Platform: The platform the user is using (e.g., website, mobile app).
# * Total Time Spent: The total time the user spends on the platform.
# * Number of Sessions: The number of times the user has logged into the platform.
# * Video ID: Unique identifier for a video.
# * Video Category: The category or genre of the video.
# * Video Length: Duration of the video.
# * Engagement: User interaction with the video (e.g., likes, comments, shares).
# * Importance Score: A score indicating how important the video is to the user.
# * Time Spent On Video: The amount of time the user spends watching a video.
# * Number of Videos Watched: The total number of videos watched by the user.
# * Scroll Rate: The rate at which the user scrolls through content.
# * Frequency: How often the user engages with the platform.
# * Productivity Loss: The impact of platform usage on the user's productivity.
# * Satisfaction: The user's satisfaction level with the platform or content.
# * Watch Reason: The reason why the user is watching a video (e.g., entertainment, education).
# * Device Type: The type of device the user is using (e.g., smartphone, tablet, desktop).
# * OS: The operating system of the user's device (e.g., iOS, Android, Windows).
# * Watch Time: The time of day when the user watches videos.
# * Self Control: The user's ability to control their usage of the platform.
# * Addiction Level: The user's level of dependency on the platform.
# * Current Activity: What the user is doing while watching the video.
# * Connection Type: The type of internet connection the user has (e.g., Wi-Fi, cellular).

# %% [markdown]
# ## Insight
#
# finding the Best time to advertize the Add of the company

# %%
data.isnull().sum()
# Out:
# UserID                      0
# Age                         0
# Gender                      0
# Location                    0
# Income                      0
# Debt                        0
# Owns Property               0
# Profession                  0
# Demographics                0
# Platform                    0
# Total Time Spent            0
# Number of Sessions          0
# Video ID                    0
# Video Category              0
# Video Length                0
# Engagement                  0
# Importance Score            0
# Time Spent On Video         0
# Number of Videos Watched    0
# Scroll Rate                 0
# Frequency                   0
# ProductivityLoss            0
# Satisfaction                0
# Watch Reason                0
# DeviceType                  0
# OS                          0
# Watch Time                  0
# Self Control                0
# Addiction Level             0
# CurrentActivity             0
# ConnectionType              0
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   UserID                    1000 non-null   int64
#  1   Age                       1000 non-null   int64
#  2   Gender                    1000 non-null   object
#  3   Location                  1000 non-null   object
#  4   Income                    1000 non-null   int64
#  5   Debt                      1000 non-null   bool
#  6   Owns Property             1000 non-null   bool
#  7   Profession                1000 non-null   object
#  8   Demographics              1000 non-null   object
#  9   Platform                  1000 non-null   object
#  10  Total Time Spent          1000 non-null   int64
#  11  Number of Sessions        1000 non-null   int64
#  12  Video ID                  1000 non-null   int64
#  13  Video Category            1000 non-null   object
# ...

# %%
data.nunique()
# Out:
# UserID                      1000
# Age                           47
# Gender                         3
# Location                      10
# Income                       996
# Debt                           2
# Owns Property                  2
# Profession                     9
# Demographics                   2
# Platform                       4
# Total Time Spent             278
# Number of Sessions            19
# Video ID                     947
# Video Category                 9
# Video Length                  29
# Engagement                   953
# Importance Score               9
# Time Spent On Video           29
# Number of Videos Watched      49
# Scroll Rate                   99
# Frequency                      4
# ProductivityLoss               9
# Satisfaction                   9
# Watch Reason                   4
# DeviceType                     3
# OS                             4
# Watch Time                    16
# Self Control                   8
# ...

# %%
data.dtypes
# Out:
# UserID                       int64
# Age                          int64
# Gender                      object
# Location                    object
# Income                       int64
# Debt                          bool
# Owns Property                 bool
# Profession                  object
# Demographics                object
# Platform                    object
# Total Time Spent             int64
# Number of Sessions           int64
# Video ID                     int64
# Video Category              object
# Video Length                 int64
# Engagement                   int64
# Importance Score             int64
# Time Spent On Video          int64
# Number of Videos Watched     int64
# Scroll Rate                  int64
# Frequency                   object
# ProductivityLoss             int64
# Satisfaction                 int64
# Watch Reason                object
# DeviceType                  object
# OS                          object
# Watch Time                  object
# ...

# %%
data.describe().T
# Out:
#                            count       mean           std      min       25%  \
# UserID                    1000.0    500.500    288.819436      1.0    250.75
# Age                       1000.0     40.986     13.497852     18.0     29.00
# Income                    1000.0  59524.213  23736.212925  20138.0  38675.25
# Total Time Spent          1000.0    151.406     83.952637     10.0     78.00
# Number of Sessions        1000.0     10.013      5.380314      1.0      6.00
# Video ID                  1000.0   4891.738   2853.144258     11.0   2542.00
# Video Length              1000.0     15.214      8.224953      1.0      8.00
# Engagement                1000.0   4997.159   2910.053701     15.0   2415.75
# Importance Score          1000.0      5.129      2.582834      1.0      3.00
# Time Spent On Video       1000.0     14.973      8.200092      1.0      8.00
# Number of Videos Watched  1000.0     25.248     14.029159      1.0     14.00
# ...

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data)
plt.xticks(rotation=90);

# %% [markdown]
# - In this there is no outliers presented

# %%
plt.figure(figsize=(10,6))
data.groupby('Platform')['Total Time Spent'].sum().plot(kind='pie',explode=(0,0,.1,0),shadow=True,autopct="%1.2f%%");
plt.title('Platform Which User Spend More');

# %% [markdown]
# - TikTok is the platform where users uses most

# %%
loc=data.groupby(['Location','Platform'])['Total Time Spent'].sum()

# %%
loc
# Out:
# Location       Platform
# Barzil         Facebook      2604
#                Instagram     3399
#                TikTok        3506
#                YouTube       1891
# Germany        Facebook      1563
#                Instagram     2429
#                TikTok        1555
#                YouTube       2176
# India          Facebook      7057
#                Instagram     6813
#                TikTok       11290
#                YouTube       9305
# Indonesia      Facebook       824
#                Instagram     2733
#                TikTok        2930
#                YouTube       4842
# Japan          Facebook      2701
#                Instagram     2980
#                TikTok        3959
#                YouTube       2635
# Mexico         Facebook      4454
#                Instagram     1721
#                TikTok        2387
#                YouTube       3158
# Pakistan       Facebook      2623
#                Instagram     5168
#                TikTok        2305
# ...

# %%
df=pd.DataFrame(loc)

# %%
df
# Out:
#                          Total Time Spent
# Location      Platform
# Barzil        Facebook               2604
#               Instagram              3399
#               TikTok                 3506
#               YouTube                1891
# Germany       Facebook               1563
#               Instagram              2429
#               TikTok                 1555
#               YouTube                2176
# India         Facebook               7057
#               Instagram              6813
#               TikTok                11290
#               YouTube                9305
# Indonesia     Facebook                824
#               Instagram              2733
#               TikTok                 2930
#               YouTube                4842
# Japan         Facebook               2701
#               Instagram              2980
#               TikTok                 3959
#               YouTube                2635
# Mexico        Facebook               4454
# ...

# %%
plt.figure(figsize=(8,4))
sns.barplot(x='Location',y='Total Time Spent',hue='Platform',data=df)
plt.xticks(rotation=90)
plt.title('Total Time Spend On Different Platforms In Different Countries');

# %% [markdown]
# - Country Based Total Time Spend On Different Platforms

# %%
data['Watch Time'].unique()
# Out:
# array(['9:00 PM', '5:00 PM', '2:00 PM', '8:00 AM', '8:30 PM', '3:45 PM',
#        '6:05 PM', '9:15 AM', '7:45 AM', '7:25 PM', '3:55 PM', '11:30 PM',
#        '10:15 PM', '9:55 AM', '4:25 PM', '5:45 PM'], dtype=object)

# %%
watch_time_distribution=data['Watch Time'].value_counts().plot(kind='bar',color='green',title='Distribution of video watch time across different times of day',ylabel='counts');

# %% [markdown]
# -It clearly shows that more people uses social media at the time 2 pm

# %%
# Filter times that are PM and greater than or equal to 9:00 PM
after_9pm = data[data['Watch Time'].str.contains('PM') & data['Watch Time'].str[:2].isin(['9:', '10', '11'])]
after_9pm
# Out:
#      UserID  Age  Gender       Location  Income   Debt  Owns Property  \
# 0         1   56    Male       Pakistan   82812   True           True
# 3         4   60    Male         Barzil   62963   True          False
# 5         6   38    Male        Vietnam   45279  False          False
# 7         8   36    Male         Barzil   39715  False          False
# 8         9   40    Male  United States   49309  False          False
# ..      ...  ...     ...            ...     ...    ...            ...
# 993     994   23  Female          India   75751   True           True
# 994     995   27    Male  United States   98915   True          False
# 996     997   40  Female       Pakistan   27006  False          False
# 997     998   27    Male          India   94218   True           True
# 998     999   61    Male       Pakistan   85344   True          False
#
#         Profession Demographics   Platform  Total Time Spent  \
# 0         Engineer        Rural  Instagram                80
# ...

# %%
data['Frequency'].unique()
# Out:
# array(['Night', 'Afternoon', 'Evening', 'Morning'], dtype=object)

# %%
a=data.groupby(['Frequency','Gender'])['Time Spent On Video'].sum()

# %%
freq=pd.DataFrame(a)

# %%
freq
# Out:
#                   Time Spent On Video
# Frequency Gender
# Afternoon Female                  988
#           Male                   1710
#           Other                   671
# Evening   Female                 1513
#           Male                   2812
#           Other                  1119
# Morning   Female                  576
#           Male                    828
#           Other                   234
# Night     Female                 1571
#           Male                   2413
#           Other                   538

# %%
sns.barplot(x='Frequency',y='Time Spent On Video',hue='Gender',data=freq)
plt.title('Total Time spend on watching the videos');

# %% [markdown]
# -It shows that either male,female or others total time spend on watching the videos

# %%
data
# Out:
#      UserID  Age  Gender       Location  Income   Debt  Owns Property  \
# 0         1   56    Male       Pakistan   82812   True           True
# 1         2   46  Female         Mexico   27999  False           True
# 2         3   32  Female  United States   42436  False           True
# 3         4   60    Male         Barzil   62963   True          False
# 4         5   25    Male       Pakistan   22096  False           True
# ..      ...  ...     ...            ...     ...    ...            ...
# 995     996   22    Male          India   74254   True           True
# 996     997   40  Female       Pakistan   27006  False          False
# 997     998   27    Male          India   94218   True           True
# 998     999   61    Male       Pakistan   85344   True          False
# 999    1000   19    Male          India   53840   True           True
#
#         Profession Demographics   Platform  Total Time Spent  \
# 0         Engineer        Rural  Instagram                80
# ...

# %%
b=data.groupby(['Platform','Frequency'])['Total Time Spent'].sum()

# %%
fre=pd.DataFrame(b)

# %%
sns.barplot(x='Platform',y='Total Time Spent',hue='Frequency',data=fre)
plt.title('Frequency Of Total Time Spend On Different Platforms');

# %% [markdown]
# -Shows that Total time spend on social media at which time

# %%
dataheat=data.select_dtypes(include='number')

# %%
plt.figure(figsize=(10,6))
sns.heatmap(dataheat.corr(),annot=True)
plt.title('heatmap showing corrilation of data');

# %% [markdown]
# - here Satisfaction and Addiction Level,ProductivityLoss and Self Control, have high corrilation and ProductivityLoss and Addiction Level,Satisfaction and Self Control have low corrilation

# %%
sns.countplot(x='Frequency',data=data);

# %% [markdown]
# this shows that evening is the best time that people are using social media more

# %%
data['Age'].unique()
# Out:
# array([56, 46, 32, 60, 25, 38, 36, 40, 28, 41, 53, 57, 20, 39, 19, 61, 47,
#        55, 50, 29, 42, 44, 59, 45, 33, 64, 54, 24, 26, 35, 21, 31, 43, 37,
#        52, 34, 23, 51, 27, 48, 62, 58, 18, 22, 30, 49, 63])

# %%
data['Watch Time'].nunique()
# Out:
# 16

# %%
sns.lineplot(x='Frequency',y='Age',data=data);

# %%
data['Profession'].unique()
# Out:
# array(['Engineer', 'Artist', 'Waiting staff', 'Manager', 'driver',
#        'Students', 'Labor/Worker', 'Cashier', 'Teacher'], dtype=object)

# %%
c=data.groupby(['Profession','Platform'])['Total Time Spent'].sum()

# %%
pro=pd.DataFrame(c)

# %%
pro
# Out:
#                          Total Time Spent
# Profession    Platform
# Artist        Facebook               1004
#               Instagram              2213
#               TikTok                 1172
#               YouTube                2801
# Cashier       Facebook               1680
#               Instagram              1830
#               TikTok                 2562
#               YouTube                3498
# Engineer      Facebook               1655
#               Instagram              2684
#               TikTok                 3218
#               YouTube                2003
# Labor/Worker  Facebook               5592
#               Instagram              8104
#               TikTok                 8491
#               YouTube                6737
# Manager       Facebook               2587
#               Instagram              1582
#               TikTok                 1557
#               YouTube                2508
# Students      Facebook               8086
# ...

# %%
plt.figure(figsize=(8,4))
sns.barplot(x='Profession',y='Total Time Spent',hue='Platform',data=pro)
plt.xticks(rotation=90)
plt.title('Time spend on different platforms on the basis of different professions');
